# %%
import pandas as pd

# %%
df =pd.read_csv("data/hot_100.csv")

# %%
df.head()
# Out:
#          date  rank           song                         artist  last-week  \
# 0  2021-11-06     1     Easy On Me                          Adele        1.0
# 1  2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2  2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3  2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4  2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  object
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 17.6+ MB

# %%
df['date'] = pd.to_datetime(df["date"])

# %%
pd.DatetimeIndex(df['date']).year.unique()
# Out:
# Int64Index([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011,
#             2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000,
#             1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989,
#             1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978,
#             1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967,
#             1966, 1965, 1964, 1963, 1962, 1961, 1960, 1959, 1958],
#            dtype='int64', name='date')

# %%
df.isnull().sum()
# Out:
# date                  0
# rank                  0
# song                  0
# artist                0
# last-week         32312
# peak-rank             0
# weeks-on-board        0
# dtype: int64

# %%
df["song"].value_counts()
# Out:
# Stay             224
# Angel            205
# Hold On          202
# You              195
# Heaven           194
#                 ...
# Privilege          1
# Six Thirty         1
# Lord Above         1
# Yesterday Man      1
# Views              1
# Name: song, Length: 24620, dtype: int64

# %%
kanye = df[df["artist"] == "Kanye West"]

# %%
df[df['weeks-on-board']==13]
# Out:
#              date  rank                                           song  \
# 32     2021-11-06    33                              Happier Than Ever
# 38     2021-11-06    39                                    Cold As You
# 47     2021-11-06    48                                         Gyalis
# 56     2021-11-06    57                                        Baddest
# 62     2021-11-06    63                                          Woman
# ...           ...   ...                                            ...
# 328861 1958-10-27    75  She Was Only Seventeen (He Was One Year More)
# 328862 1958-10-27    76                            Somebody Touched Me
# 328865 1958-10-27    79                            Are You Really Mine
# 328877 1958-10-27    91                                   Stupid Cupid
# 328879 1958-10-27    93                Volare (Nel Blu Dipinto Di Blu)
#
#                                     artist  last-week  peak-rank  \
# ...

# %%
kanye[kanye["song"]=='Stronger']
# Out:
#             date  rank      song      artist  last-week  peak-rank  \
# 71745 2008-02-09    46  Stronger  Kanye West       38.0          1
# 71837 2008-02-02    38  Stronger  Kanye West       34.0          1
# 71933 2008-01-26    34  Stronger  Kanye West       22.0          1
# 72021 2008-01-19    22  Stronger  Kanye West       14.0          1
# 72113 2008-01-12    14  Stronger  Kanye West       20.0          1
# 72219 2008-01-05    20  Stronger  Kanye West       17.0          1
# 72316 2007-12-29    17  Stronger  Kanye West       13.0          1
# 72412 2007-12-22    13  Stronger  Kanye West       13.0          1
# 72512 2007-12-15    13  Stronger  Kanye West       13.0          1
# 72612 2007-12-08    13  Stronger  Kanye West       10.0          1
# 72709 2007-12-01    10  Stronger  Kanye West        9.0          1
# 72808 2007-11-24     9  Stronger  Kanye West        6.0          1
# 72905 2007-11-17     6  Stronger  Kanye West        6.0          1
# ...

# %%
df["artist"].nunique()
# Out:
# 10205

# %%
onlysongs = df[["song","artist"]]

# %%
onlysongs
# Out:
#                                        song                         artist
# 0                                Easy On Me                          Adele
# 1                                      Stay  The Kid LAROI & Justin Bieber
# 2                             Industry Baby        Lil Nas X & Jack Harlow
# 3                                Fancy Like                   Walker Hayes
# 4                                Bad Habits                     Ed Sheeran
# ...                                     ...                            ...
# 330082                        Over And Over                Thurston Harris
# 330083                     I Believe In You                Robert & Johnny
# 330084                      Little Serenade              The Ames Brothers
# 330085  I'll Get By (As Long As I Have You)                 Billy Williams
# 330086                                 Judy                Frankie Vaughan
#
# [330087 rows x 2 columns]

# %%
onlysongs.duplicated(subset=["song","artist"])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 330082    False
# 330083     True
# 330084    False
# 330085    False
# 330086    False
# Length: 330087, dtype: bool

# %%
kanye = df[df["song"] == "Stronger"]

# %%
kanye["dup"] = kanye.duplicated(subset=["song","artist"])
# Out:
# D:\Users\Alfaisal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
kanye[kanye["dup"] == False]
# Out:
#              date  rank      song          artist  last-week  peak-rank  \
# 57752  2010-10-16    53  Stronger       Glee Cast        NaN         53
# 71745  2008-02-09    46  Stronger      Kanye West       38.0          1
# 107873 2001-03-10    74  Stronger  Britney Spears       69.0         11
#
#         weeks-on-board    dup
# 57752                1  False
# 71745               27  False
# 107873              15  False

# %%
df["is_duplicate"] = df.duplicated(subset=["song","artist"])

# %%
non_dup_list = df[df["is_duplicate"] == False].reset_index()

# %%
non_dup_list.drop(columns=["index","is_duplicate"])
# Out:
#             date  rank                                 song  \
# 0     2021-11-06     1                           Easy On Me
# 1     2021-11-06     2                                 Stay
# 2     2021-11-06     3                        Industry Baby
# 3     2021-11-06     4                           Fancy Like
# 4     2021-11-06     5                           Bad Habits
# ...          ...   ...                                  ...
# 29676 1958-08-04    90                                 Stay
# 29677 1958-08-04    96                        Over And Over
# 29678 1958-08-04    98                      Little Serenade
# 29679 1958-08-04    99  I'll Get By (As Long As I Have You)
# 29680 1958-08-04   100                                 Judy
#
#                               artist  last-week  peak-rank  weeks-on-board
# 0                              Adele        1.0          1               3
# 1      The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
non_dup_list
# Out:
#         index       date  rank                                 song  \
# 0           0 2021-11-06     1                           Easy On Me
# 1           1 2021-11-06     2                                 Stay
# 2           2 2021-11-06     3                        Industry Baby
# 3           3 2021-11-06     4                           Fancy Like
# 4           4 2021-11-06     5                           Bad Habits
# ...       ...        ...   ...                                  ...
# 29676  330076 1958-08-04    90                                 Stay
# 29677  330082 1958-08-04    96                        Over And Over
# 29678  330084 1958-08-04    98                      Little Serenade
# 29679  330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 29680  330086 1958-08-04   100                                 Judy
#
#                               artist  last-week  peak-rank  weeks-on-board  \
# ...
