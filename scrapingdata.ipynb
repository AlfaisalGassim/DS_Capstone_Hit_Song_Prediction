# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import io
import numpy as np

# %%
# Create an URL object
url = 'https://www.billboard.com/charts/hot-100/2021-01-16/'
# Create object page
page = requests.get(url)

# %%
# parser-lxml = Change html to Python friendly format
# Obtain page's information
soup = BeautifulSoup(page.text, 'lxml')

# %%
# Obtain information from tag <div>
div1 = soup.find('div', {'class':'chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max'})

# %%
div2 = div1.find_all('div', {'class':'o-chart-results-list-row-container'})

# %%
len(div2)
# Out:
# 100

# %%
div2
# Out:
# [<div class="o-chart-results-list-row-container">
#  <ul class="o-chart-results-list-row // lrv-a-unstyle-list lrv-u-flex u-height-200 u-height-100@mobile-max u-height-100@tablet-only lrv-u-background-color-white a-chart-has-chart-detail" data-ajax="" data-detail-target="1">
#  <li class="o-chart-results-list__item // lrv-u-background-color-black lrv-u-color-white u-width-100 u-width-55@mobile-max u-width-55@tablet-only lrv-u-height-100p lrv-u-flex lrv-u-flex-direction-column@mobile-max lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey">
#  <span class="c-label a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet">
#  1
#  </span>
#  <div class="c-svg u-height-10@mobile-max u-width-10@mobile-max u-hidden@tablet">
# ...

# %%
test = div2[0].find('span', {'class':'c-label a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet'})

# %%
test = div1.find_all('li',{'class':'lrv-u-width-100p'})

# %%
div2[1]
# Out:
# <div class="o-chart-results-list-row-container">
# <ul class="o-chart-results-list-row // lrv-a-unstyle-list lrv-u-flex u-height-100 lrv-u-background-color-white a-chart-has-chart-detail" data-ajax="" data-detail-target="2">
# <li class="o-chart-results-list__item // lrv-u-background-color-black lrv-u-color-white u-width-100 u-width-55@mobile-max u-width-55@tablet-only lrv-u-height-100p lrv-u-flex lrv-u-flex-direction-column@mobile-max lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey">
# <span class="c-label a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet">
# 2
# </span>
# <div class="c-svg u-height-10@mobile-max u-width-10@mobile-max u-hidden@tablet">
# <svg height="10.157" width="10.157" xmlns="http://www.w3.org/2000/svg"><path d="M7.727 5.732H0V4.426h7.727L4.322.923 5.219 0l4.938 5.079-4.938 5.079-.9-.923z" data-name="Arrow" fill="#8289a1"></path></svg></div>
# </li>
# ...

# %%
# Obtain every title of columns with tag <th>
ranks = []
songs= []
x =0
for i in div2:
    x = i.find('span', {'class':'c-label a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet'})
    rank = x.text
    ranks.append(rank)
    y = i.find('h3')
    song = y.text
    songs.append(song)

# %%
songs
# Out:
# ['\nMood\n',
#  '\nPositions\n',
#  '\nBlinding Lights\n',
#  '\nHoly\n',
#  '\nGo Crazy\n',
#  '\nAnyone\n',
#  '\nLevitating\n',
#  '\nLaugh Now Cry Later\n',
#  '\nBang!\n',
#  '\nI Hope\n',
#  '\nFor The Night\n',
#  '\nLemonade\n',
#  '\n34+35\n',
#  '\nTherefore I Am\n',
#  '\nKings & Queens\n',
#  '\nBody\n',
#  '\nDakiti\n',
#  '\nLonely\n',
#  '\nBetter Together\n',
#  '\nWhat You Know Bout Love\n',
#  '\nWhoopty\n',
#  '\nWillow\n',
#  '\nGood Days\n',
#  '\nBefore You Go\n',
#  '\nDynamite\n',
#  '\nRockstar\n',
#  '\nMore Than My Hometown\n',
#  '\nI Should Probably Go To Bed\n',
#  '\nAfterglow\n',
#  '\nStarting Over\n',
#  '\nSavage Love (Laxed - Siren Beat)\n',
#  '\nHappy Anywhere\n',
#  '\nChampagne Night\n',
#  '\nWhats Poppin\n',
#  '\nWAP\n',
#  '\nMonster\n',
#  '\nPretty Heart\n',
#  '\nOn Me\n',
#  '\nDiamonds\n',
#  '\nYou Broke Me First.\n',
#  "\nMy Ex's Best Friend\n",
#  '\nWatermelon Sugar\n',
#  '\nHawai\n',
#  '\nCry Baby\n',
# ...

# %%
len(headers)
# Out:
# 100

# %%
type(headers)
# Out:
# list

# %%
# Create a dataframe
mydata = pd.DataFrame(headers)

# %%
mydata
# Out:
#                                                     0
# 0   \n\n\n\n1\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 1   \n\n\n\n2\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 2   \n\n\n\n3\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 3   \n\n\n\n4\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 4   \n\n\n\n5\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ..                                                ...
# 95  \n\n\n\n96\n\n\nRE-\nENTRY\n\n\n\n\n\n\n\n\n\n...
# 96  \n\n\n\n97\n\n\nNEW\n\n\n\n\n\n\n\n\n\n\n\nNEW...
# 97  \n\n\n\n98\n\n\nRE-\nENTRY\n\n\n\n\n\n\n\n\n\n...
# 98  \n\n\n\n99\n\n\nRE-\nENTRY\n\n\n\n\n\n\n\n\n\n...
# 99  \n\n\n\n100\n\n\nNEW\n\n\n\n\n\n\n\n\n\n\n\nNE...
#
# [100 rows x 1 columns]

# %%
mydata.rename(columns = {'0': 'allstring'}, inplace = True)
mydata
# Out:
#                                                     0
# 0   \n\n\n\n1\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 1   \n\n\n\n2\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 2   \n\n\n\n3\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 3   \n\n\n\n4\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 4   \n\n\n\n5\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ..                                                ...
# 95  \n\n\n\n96\n\n\nRE-\nENTRY\n\n\n\n\n\n\n\n\n\n...
# 96  \n\n\n\n97\n\n\nNEW\n\n\n\n\n\n\n\n\n\n\n\nNEW...
# 97  \n\n\n\n98\n\n\nRE-\nENTRY\n\n\n\n\n\n\n\n\n\n...
# 98  \n\n\n\n99\n\n\nRE-\nENTRY\n\n\n\n\n\n\n\n\n\n...
# 99  \n\n\n\n100\n\n\nNEW\n\n\n\n\n\n\n\n\n\n\n\nNE...
#
# [100 rows x 1 columns]

# %%
pd.DataFrame(io.StringIO('\n'.join( mydata)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-0b9e93741083> in <module>()
# ----> 1 pd.DataFrame(io.StringIO('\n'.join( mydata)))
#
# TypeError: sequence item 0: expected str instance, int found

# %%
mydata['0'].str.split()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-f8ce2ee41374> in <module>()
# ----> 1 mydata['0'].str.split()
#
# D:\Users\Alfaisal\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# D:\Users\Alfaisal\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: '0'

# %%
type(headers[1])
# Out:
# str

# %%
headers[0].strip()
headers[0]
# Out:
# '\n\n\n\n1\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMood\n\n\n24kGoldn Featuring iann dior\n\n\n\n\n\n\n\n\n\n\n\n1\n\n\n\n\n1\n\n\n\n\n22\n\n\n\n\n\n\n\n\n\n\n\n\n\n1\n\n\n\n\n1\n\n\n\n\n22\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCredits\n\nAwards\n\nShare\n\n\n\n\nSongwriter(s):\n\nG.L.von Jones, O.Fedi, B.Slatktin, K.C.Bach, M.I.Olmo\n\nProducer(s):\n\nO.Fedi, B.Slatkin, KBeaZy\n\nImprint/Promotion Label:\n\nRECORDS/Columbia\n\n\n\n\n\n\n\nGains In Performance\n\n\n\n\n\n\nShare Chart on Twitter\n\n\n\n\nTwitter\n\n\n\nShare Chart on Copy Link\n\n\n\n\nCopy Link\n\n\n\nShare Chart on Facebook\n\n\n\n\nFacebook\n\n\n\nShare Chart on Embed\n\n\n\n\nEmbed\n\n\n\n\n\n\n\n\n\nRIAA Certification:\n\n\nPlatinum x5\n\n\n\n'

# %%
rez = []
for x in headers:
    rez.append(x.replace("\n", ","))

# %%
rez1 = []
for x in rez:
    rez1.append(x.replace("NEW", ""))

# %%
rez
# Out:
# [',,,,1,,,,,,,,,,,,,,,,,,,,Mood,,,24kGoldn Featuring iann dior,,,,,,,,,,,,1,,,,,1,,,,,22,,,,,,,,,,,,,,1,,,,,1,,,,,22,,,,,,,,,,,,,,,,,,,,,Credits,,Awards,,Share,,,,,Songwriter(s):,,G.L.von Jones, O.Fedi, B.Slatktin, K.C.Bach, M.I.Olmo,,Producer(s):,,O.Fedi, B.Slatkin, KBeaZy,,Imprint/Promotion Label:,,RECORDS/Columbia,,,,,,,,Gains In Performance,,,,,,,Share Chart on Twitter,,,,,Twitter,,,,Share Chart on Copy Link,,,,,Copy Link,,,,Share Chart on Facebook,,,,,Facebook,,,,Share Chart on Embed,,,,,Embed,,,,,,,,,,RIAA Certification:,,,Platinum x5,,,,',
# ...

# %%
rez2 =[]
for x in rez1:
    rez2.append(x.replace("RE-", ""))

# %%
rez3 =[]
for x in rez2:
    rez3.append(x.replace("ENTRY", ""))

# %%
np.savetxt("GFGF.csv", 
           rez,
           delimiter =",", 
           fmt ='% s')

# %%
mydata
# Out:
#                                                     0
# 0   ,,,,1,,,,,,,,,,,,,,,,,,,,Mood,,,24kGoldn Featu...
# 1   ,,,,2,,,,,,,,,,,,,,,,,,,,Positions,,,Ariana Gr...
# 2   ,,,,3,,,,,,,,,,,,,,,,,,,,Blinding Lights,,,The...
# 3   ,,,,4,,,,,,,,,,,,,,,,,,,,Holy,,,Justin Bieber ...
# 4   ,,,,5,,,,,,,,,,,,,,,,,,,,Go Crazy,,,Chris Brow...
# ..                                                ...
# 95  ,,,,96,,,RE-,ENTRY,,,,,,,,,,,,RE-,ENTRY,,,,,,,...
# 96  ,,,,97,,,NEW,,,,,,,,,,,,NEW,,,,,,,Lady,,,Brett...
# 97  ,,,,98,,,RE-,ENTRY,,,,,,,,,,,,RE-,ENTRY,,,,,,,...
# 98  ,,,,99,,,RE-,ENTRY,,,,,,,,,,,,RE-,ENTRY,,,,,,,...
# 99  ,,,,100,,,NEW,,,,,,,,,,,,NEW,,,,,,,Heat Waves,...
#
# [100 rows x 1 columns]

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
mydata1 = mydata["all"].str.split()

# %%
type(mydata1)
# Out:
# pandas.core.series.Series

# %%
mydata2 = pd.DataFrame(mydata1)

# %%
mydata2
# Out:
#                                                   all
# 0   [1, Mood, 24kGoldn, Featuring, iann, dior, 1, ...
# 1   [2, Positions, Ariana, Grande, 2, 1, 11, 2, 1,...
# 2   [3, Blinding, Lights, The, Weeknd, 3, 1, 57, 3...
# 3   [4, Holy, Justin, Bieber, Featuring, Chance, T...
# 4   [5, Go, Crazy, Chris, Brown, &, Young, Thug, 6...
# ..                                                ...
# 95  [96, Everywhere, But, On, Matt, Stell, -, 48, ...
# 96  [97, Lady, Brett, Young, -, 97, 1, -, 97, 1, C...
# 97  [98, Still, Goin, Down, Morgan, Wallen, -, 46,...
# 98  [99, Reminds, Me, Of, You, The, Kid, LAROI, &,...
# 99  [100, Heat, Waves, Glass, Animals, -, 100, 1, ...
#
# [100 rows x 1 columns]

# %%
mydata3 = pd.DataFrame(mydata2['all'].to_list())

# %%
mydata3.head()
# Out:
#   0          1         2          3          4       5      6       7   8   \
# 0  1       Mood  24kGoldn  Featuring       iann    dior      1       1  22
# 1  2  Positions    Ariana     Grande          2       1     11       2   1
# 2  3   Blinding    Lights        The     Weeknd       3      1      57   3
# 3  4       Holy    Justin     Bieber  Featuring  Chance    The  Rapper   4
# 4  5         Go     Crazy      Chris      Brown       &  Young    Thug   6
#
#    9   ...     64     65    66     67     68    69              70        71  \
# 0   1  ...   None   None  None   None   None  None            None      None
# 1  11  ...   None   None  None   None   None  None            None      None
# 2   1  ...   None   None  None   None   None  None            None      None
# 3   3  ...   None   None  None   None   None  None            None      None
# 4   5  ...  Share  Chart    on  Embed  Embed  RIAA  Certification:  Platinum
#
#      72    73
# 0  None  None
# 1  None  None
# ...

# %%
mydata3[[1]]
# Out:
#              1
# 0         Mood
# 1    Positions
# 2     Blinding
# 3         Holy
# 4           Go
# ..         ...
# 95  Everywhere
# 96        Lady
# 97       Still
# 98     Reminds
# 99        Heat
#
# [100 rows x 1 columns]
